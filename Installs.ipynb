# %%
# Install Python 3.9 and update alternatives
# !sudo apt-get update -y
# !sudo apt-get install python3.9
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 2
# !sudo update-alternatives --config python3  # Select Python 3.9 when prompted

# Install essential tools and reconfigure Colab dependencies
# !sudo apt-get install python3.9-distutils
# !wget https://bootstrap.pypa.io/get-pip.py
# !python get-pip.py --force-reinstall
# !python -m pip install --upgrade ipython ipython_genutils ipykernel jupyter_console prompt_toolkit httplib2 astor

# Link Colab's internal packages to new Python installation
# !ln -sf /usr/local/lib/python3.8/dist-packages/google /usr/local/lib/python3.9/dist-packages/google

# # Restart runtime to apply changes
# import os
# os.kill(os.getpid(), 9)

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# ...
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydantic 2.10.6 requires typing-extensions>=4.12.2, but you have typing-extensions 4.8.0 which is incompatible.
# ...

# %%
# !pip install -r not_included.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 107.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 72.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 83.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.5/549.5 MB 75.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 105.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 48.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.1/803.1 kB 40.2 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers==4.34.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 150.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.0
#     Uninstalling transformers-4.35.0:
#       Successfully uninstalled transformers-4.35.0
# ...

# %%
# Remove existing NCCL installation
# !pip uninstall nvidia-nccl

# Install from NVIDIA's PyPI index
# !pip install nvidia-nccl-cu12==2.20.5 -f https://pypi.nvidia.com
# Out:
# WARNING: Skipping nvidia-nccl as it is not installed.
# Looking in links: https://pypi.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 227.7 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.19.3
#     Uninstalling nvidia-nccl-cu12-2.19.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.19.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.2.1+cu121 requires nvidia-nccl-cu12==2.19.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nccl-cu12 2.20.5 which is incompatible.
# ...
